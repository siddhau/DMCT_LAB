# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('housing.csv')
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing = pd.DataFrame(data)

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
x = housing["ocean_proximity"].unique()

# %%
x
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
gr1 = housing.groupby("ocean_proximity")
gr2= housing.groupby("ocean_proximity")["median_house_value"].mean()

# %%
gr1.groups
gr2
# Out:
# ocean_proximity
# <1H OCEAN     240084.285464
# INLAND        124805.392001
# ISLAND        380440.000000
# NEAR BAY      259212.311790
# NEAR OCEAN    249433.977427
# Name: median_house_value, dtype: float64

# %%
gr2.plot.bar()

# %%
import numpy as np
from sklearn import preprocessing
# ax = housing[['population']].values.astype(float)
# min_max_scalor = preprocessing.MinMaxScaler()
# x_scaled = min_max_scalor.fit_transform(ax)
# ax_norm = pd.DataFrame(x_scaled)
# ax_norm = ax_norm * 100
ax = housing["population"]/10

housing.plot.scatter(x="longitude",y="latitude",alpha=0.3,s=ax,c="median_house_value",cmap=plt.get_cmap('jet'))
fig = plt.gcf();
fig.set_size_inches(11,8)
#ax_norm

# %%
df_islands = housing[housing["ocean_proximity"] == 'INLAND']
df_near_ocean = housing[housing["ocean_proximity"] == 'NEAR OCEAN']

# %%
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 954      -121.92     37.64                46.0       1280.0           209.0
# 957      -121.90     37.66                18.0       7397.0          1137.0
# 965      -121.88     37.68                23.0       2234.0           270.0
# 967      -121.88     37.67                16.0       4070.0           624.0
# 968      -121.88     37.67                25.0       2244.0           301.0
# 969      -121.89     37.67                20.0       2948.0           471.0
# 970      -121.89     37.67                19.0       2034.0           288.0
# 973      -121.88     37.66                29.0       2702.0           680.0
# 974      -121.87     37.66                39.0        522.0           116.0
# 975      -121.87     37.66                52.0        775.0           134.0
# 976      -121.89     37.66                 3.0       1565.0           464.0
# ...

# %%
len(df_islands)
# Out:
# 6551

# %%
p_island = df_islands["population"].mean()
p_near_ocean = df_near_ocean["population"].mean()

# %%
pop = [p_island,p_near_ocean]

# %%
pop = pd.DataFrame(pop)
pop
# Out:
#              0
# 0  1391.046252
# 1  1354.008653

# %%
pop.plot.bar()
